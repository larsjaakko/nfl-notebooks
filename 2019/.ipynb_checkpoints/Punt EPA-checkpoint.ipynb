# %% [markdown]
# # 2019 Mitch Watch

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob

from scipy.interpolate import make_interp_spline, BSpline

sns.set(style="whitegrid", 
        palette="pastel", 
        font='Circular Spotify Text', 
        font_scale = 1.1, 
        rc= {'grid.color': '.95', 'xtick.color': '.3', 'ytick.color': '.3'})

# %%
team_colors = {
    'SF': '#AA0000',
    'KC': '#000000',
    'ARI': '#000000',
    'ATL': '#000000',
    'BAL': '#241773',
    'PHI': '#004953',
    'NYG': '#0B2265',
    'NO': '#9F8958',
    'NE': '#002244',
    'MIN': '#4F2683',
    'MIA': '#008E97',
    'IND': '#002C5F',
    'CLE': '#FB4F14',
    'LAC': '#002244',
    'DEN': '#002244',
    'CAR': '#0085CA',
    'GB': '#203731',
    'DET': '#005A8B',
    'OAK': '#A5ACAF',
    'CIN': '#FB4F14',
    'WAS': '#773141',
    'TEN': '#002244',
    'TB': '#000000',
    'PIT': '#FFB612',
    'NYJ': '#203731',
    'BUF': '#00338D',
    'LA': '#002244',
    'JAX': '#006778',
    'DAL': '#002244',
    'CHI': '#0B162A',
    'HOU': '#03202F',
    'SEA': '#002244'
}

team_colors_main = {
    'SF': '#AA0000',
    'KC': '#E31837',
    'ARI': '#97233F',
    'ATL': '#A71930',
    'BAL': '#241773',
    'PHI': '#004953',
    'NYG': '#0B2265',
    'NO': '#9F8958',
    'NE': '#002244',
    'MIN': '#4F2683',
    'MIA': '#008E97',
    'IND': '#002C5F',
    'CLE': '#FB4F14',
    'LAC': '#002244',
    'DEN': '#002244',
    'CAR': '#0085CA',
    'GB': '#203731',
    'DET': '#005A8B',
    'OAK': '#A5ACAF',
    'CIN': '#FB4F14',
    'WAS': '#773141',
    'TEN': '#002244',
    'TB': '#D50A0A',
    'PIT': '#FFB612',
    'NYJ': '#203731',
    'BUF': '#00338D',
    'LA': '#002244',
    'JAX': '#006778',
    'DAL': '#002244',
    'CHI': '#0B162A',
    'HOU': '#03202F',
    'SEA': '#002244'
}

team_colors_gray = {
    
    'SF': '#AA0000',
    'KC': '#D9D9D9',
    'ARI': '#D9D9D9',
    'ATL': '#D9D9D9',
    'BAL': '#D9D9D9',
    'PHI': '#D9D9D9',
    'NYG': '#D9D9D9',
    'NO': '#D9D9D9',
    'NE': '#D9D9D9',
    'MIN': '#D9D9D9',
    'MIA': '#D9D9D9',
    'IND': '#D9D9D9',
    'CLE': '#D9D9D9',
    'LAC': '#D9D9D9',
    'DEN': '#D9D9D9',
    'CAR': '#D9D9D9',
    'GB': '#D9D9D9',
    'DET': '#D9D9D9',
    'OAK': '#D9D9D9',
    'CIN': '#D9D9D9',
    'WAS': '#D9D9D9',
    'TEN': '#D9D9D9',
    'TB': '#D9D9D9',
    'PIT': '#D9D9D9',
    'NYJ': '#D9D9D9',
    'BUF': '#D9D9D9',
    'LA': '#D9D9D9',
    'JAX': '#D9D9D9',
    'DAL': '#D9D9D9',
    'CHI': '#D9D9D9',
    'HOU': '#D9D9D9',
    'SEA': '#D9D9D9'
}

# %% [markdown]
# ## Data

# %%
df = pd.read_csv("../data/reg_pbp_2019.csv", low_memory=False)

# %% [markdown]
# ## EPA per punt

# %%
df_punts = df[df['play_type'] == 'punt']

# %%
(df_punts.loc[:,['home_team', 
                 'away_team', 
                 'posteam', 
                 'punter_player_name', 
                 'punt_downed',
                 'epa', 
                 'return_yards', 
                 'fumble',
                 'kick_distance'
                ]]
 .sort_values('epa', ascending=False)
 .head(20))
# Out:
#      home_team away_team posteam punter_player_name  punt_downed       epa  \
# 1617       SEA       CIN     SEA          M.Dickson          0.0  5.746275
# 960        MIA       BAL     BAL             S.Koch          0.0  5.389219
# 1526       LAC       IND     IND          R.Sanchez          0.0  4.850979
# 2184       ARI       DET     ARI              A.Lee          0.0  4.129043
# 5242       DEN       CHI     CHI        P.O'Donnell          0.0  3.338557
# 1694       SEA       CIN     SEA          M.Dickson          1.0  2.645086
# 2529        NO       HOU     HOU           T.Daniel          0.0  2.640747
# 4471       HOU       JAX     JAX            L.Cooke          0.0  2.384408
# 926        MIA       BAL     MIA            M.Haack          0.0  2.316751
# 648        NYJ       BUF     NYJ          L.Edwards          1.0  2.082166
# 4149       DET       LAC     LAC             T.Long          0.0  2.050574
# 3660       PIT       SEA     SEA          M.Dickson          0.0  2.014198
# 2353        NE       PIT      NE           J.Bailey          0.0  1.977872
# 133        CHI        GB     CHI        P.O'Donnell          0.0  1.977087
# 2163       ARI       DET     ARI              A.Lee          0.0  1.890391
# 3141       BAL       ARI     BAL             S.Koch          0.0  1.847942
# 5355       ATL       PHI     PHI         C.Johnston          1.0  1.797576
# 3274       WAS       DAL     WAS              T.Way          0.0  1.733163
# 3796       NYG       BUF     NYG            R.Dixon          1.0  1.725086
# 381        PHI       WAS     PHI         C.Johnston          0.0  1.702391
#
#       return_yards  fumble  kick_distance
# 1617             9     1.0           43.0
# 960              0     1.0           56.0
# 1526             0     1.0           39.0
# 2184             0     1.0           53.0
# 5242             0     0.0           61.0
# 1694             0     0.0           54.0
# 2529             5     0.0           54.0
# 4471             0     0.0           54.0
# 926              0     0.0           58.0
# 648              0     0.0           53.0
# 4149             1     0.0           51.0
# 3660             0     0.0           59.0
# 2353             0     0.0           53.0
# 133              0     0.0           53.0
# 2163             0     0.0           57.0
# 3141             0     0.0           44.0
# 5355             0     0.0           54.0
# 3274             0     0.0           56.0
# 3796             0     0.0           58.0
# 381             11     0.0           52.0

# %%
df_punts.groupby(['punter_player_name', 'posteam'])['epa'].mean().reset_index().sort_values('epa', ascending=False)
# Out:
#    punter_player_name posteam       epa
# 26             S.Koch     BAL  1.582522
# 29             T.Long     LAC  1.253365
# 16            L.Cooke     JAX  1.166044
# 19          M.Dickson     SEA  1.006806
# 6          C.Johnston     PHI  0.683695
# 25          R.Sanchez     IND  0.629398
# 1               A.Lee     ARI  0.587682
# 31              T.Way     WAS  0.569635
# 20            M.Haack     MIA  0.532549
# 24            R.Dixon     NYG  0.459110
# 21          M.Palardy     CAR  0.423106
# 28           T.Daniel     HOU  0.394006
# 23        P.O'Donnell     CHI  0.390470
# 10           J.Bailey      NE  0.327384
# 30         T.Morstead      NO  0.273021
# 15            K.Huber     CIN  0.215227
# 17          L.Edwards     NYJ  0.214767
# 11            J.Berry     PIT  0.184530
# 14            J.Scott      GB  0.182727
# 4            B.Pinion      TB  0.158829
# 12           J.Gillan     CLE  0.127111
# 7             C.Jones     DAL  0.123440
# 9          D.Colquitt      KC -0.001942
# 18           M.Bosher     ATL -0.025945
# 3              B.Kern     TEN -0.034138
# 2          B.Colquitt     MIN -0.088098
# 22       M.Wishnowsky      SF -0.133715
# 13           J.Hekker      LA -0.151364
# 27           S.Martin     DET -0.157864
# 0              A.Cole     OAK -0.202514
# 5         C.Bojorquez     BUF -0.278145
# 8            C.Wadman     DEN -0.290377

# %% [markdown]
# ## Return yards per punt

# %%
df_punts.groupby(['punter_player_name', 'posteam'])['return_yards'].mean().reset_index().sort_values('return_yards', ascending=True)
# Out:
#    punter_player_name posteam  return_yards
# 26             S.Koch     BAL      0.000000
# 22       M.Wishnowsky      SF      0.000000
# 15            K.Huber     CIN      0.444444
# 12           J.Gillan     CLE      0.454545
# 16            L.Cooke     JAX      0.625000
# 24            R.Dixon     NYG      0.666667
# 10           J.Bailey      NE      0.833333
# 18           M.Bosher     ATL      1.333333
# 27           S.Martin     DET      1.500000
# 9          D.Colquitt      KC      1.666667
# 8            C.Wadman     DEN      2.000000
# 28           T.Daniel     HOU      2.636364
# 7             C.Jones     DAL      2.666667
# 23        P.O'Donnell     CHI      2.769231
# 20            M.Haack     MIA      2.923077
# 25          R.Sanchez     IND      3.250000
# 6          C.Johnston     PHI      3.285714
# 1               A.Lee     ARI      3.307692
# 14            J.Scott      GB      3.588235
# 29             T.Long     LAC      3.666667
# 19          M.Dickson     SEA      3.833333
# 17          L.Edwards     NYJ      4.142857
# 2          B.Colquitt     MIN      4.181818
# 21          M.Palardy     CAR      4.444444
# 11            J.Berry     PIT      4.500000
# 4            B.Pinion      TB      4.875000
# 3              B.Kern     TEN      5.000000
# 0              A.Cole     OAK      5.333333
# 31              T.Way     WAS      5.555556
# 30         T.Morstead      NO      6.000000
# 5         C.Bojorquez     BUF      7.500000
# 13           J.Hekker      LA      9.142857

# %% [markdown]
# ## Punt distance

# %%
df_punts.groupby(['punter_player_name', 'posteam'])['kick_distance'].mean().reset_index().sort_values('kick_distance', ascending=False)
# Out:
#    punter_player_name posteam  kick_distance
# 31              T.Way     WAS      52.222222
# 6          C.Johnston     PHI      51.857143
# 29             T.Long     LAC      50.000000
# 1               A.Lee     ARI      49.166667
# 13           J.Hekker      LA      49.000000
# 21          M.Palardy     CAR      48.625000
# 23        P.O'Donnell     CHI      48.307692
# 19          M.Dickson     SEA      48.090909
# 16            L.Cooke     JAX      48.000000
# 20            M.Haack     MIA      47.692308
# 30         T.Morstead      NO      47.428571
# 14            J.Scott      GB      47.312500
# 3              B.Kern     TEN      47.083333
# 2          B.Colquitt     MIN      46.454545
# 26             S.Koch     BAL      46.250000
# 24            R.Dixon     NYG      45.333333
# 17          L.Edwards     NYJ      45.214286
# 11            J.Berry     PIT      45.200000
# 5         C.Bojorquez     BUF      45.000000
# 10           J.Bailey      NE      44.500000
# 7             C.Jones     DAL      44.333333
# 15            K.Huber     CIN      44.000000
# 28           T.Daniel     HOU      43.545455
# 0              A.Cole     OAK      43.250000
# 8            C.Wadman     DEN      43.000000
# 25          R.Sanchez     IND      42.285714
# 12           J.Gillan     CLE      42.181818
# 4            B.Pinion      TB      42.125000
# 22       M.Wishnowsky      SF      41.500000
# 18           M.Bosher     ATL      41.333333
# 27           S.Martin     DET      40.833333
# 9          D.Colquitt      KC      39.200000

# %% [markdown]
# ## Charts — EPA/punt vs avg. return yards

# %%
data = df_punts.groupby(['posteam'])['epa', 'return_yards'].mean().reset_index()
data.head()
# Out:
#   posteam       epa  return_yards
# 0     ARI  0.587682      3.307692
# 1     ATL -0.474416      1.142857
# 2     BAL  1.582522      0.000000
# 3     BUF -0.278145      7.500000
# 4     CAR  0.423106      4.444444

# %%
f, ax = plt.subplots(figsize=(12, 8))

# Plotting all other teams and adding names

others = data[data['posteam'] != 'SF'].reset_index()

ax = sns.scatterplot(x="return_yards", 
                     y="epa",
                     hue="posteam", 
                     palette=team_colors,
                     data=others,
                     legend=False,
                     alpha=0.7,
                     s=400
                    )


#ax.set_title('EPA per punt vs. return yards per punt\n', fontsize=22, weight='black')
ax.text(x=0.5, y=1.1, s='EPA per punt vs. return yards allowed per punt', fontsize=26, weight='bold', ha='center', va='bottom', transform=ax.transAxes)
ax.text(x=0.5, y=1.05, s='Through week 2 of the 2019 NFL regular season', fontsize=16, color='darkgray', ha='center', va='bottom', transform=ax.transAxes)

plt.xlim(reversed(plt.xlim()))    
        
texts = [plt.text(others['return_yards'][line]+0.015, others['epa'][line], others['posteam'][line], horizontalalignment='left', size=14, color='darkgray', weight='light') for line in range(0,others.shape[0])]
        
# Plotting and labeling SF
        
ax = sns.scatterplot(x="return_yards", 
                     y="epa",
                     hue="posteam", 
                     palette=team_colors_gray,
                     data=data[data['posteam'] == 'SF'],
                     legend=False,
                     alpha=0.8,
                     s=600
                    )

ax.set_ylabel('EPA per punt\n')
ax.set_xlabel('\nReturn yards allowed per punt')

ax.text(data[data['posteam'] == 'SF']['return_yards']+0.015, data[data['posteam'] == 'SF']['epa'], data[data['posteam'] == 'SF']['posteam'].values[0], horizontalalignment='left', size=20, color='black', weight='semibold')
sns.despine(left=True, right=True, top=True, bottom=True)

# %%
data = df_punts.groupby(['posteam'])['epa', 'kick_distance'].mean().reset_index().dropna()
data.head()
# Out:
#   posteam       epa  kick_distance
# 0     ARI  0.587573      49.166667
# 1     ATL -0.474416      41.333333
# 2     BAL  1.582522      46.250000
# 3     BUF -0.278145      45.000000
# 4     CAR  0.423106      48.625000

# %%
f, ax = plt.subplots(figsize=(12, 8))

# Plotting all other teams and adding names

others = data[data['posteam'] != 'SF'].reset_index()

ax = sns.scatterplot(x="kick_distance", 
                     y="epa",
                     hue="posteam", 
                     palette=team_colors_gray,
                     data=others,
                     legend=False,
                     alpha=0.8,
                     s=600
                    )


#ax.set_title('EPA per punt vs. return yards per punt\n', fontsize=22, weight='black')
ax.text(x=0.5, y=1.1, s='EPA per punt vs. kick distance per punt', fontsize=26, weight='bold', ha='center', va='bottom', transform=ax.transAxes)
ax.text(x=0.5, y=1.05, s='Through week 2 of the 2019 NFL regular season', fontsize=16, color='darkgray', ha='center', va='bottom', transform=ax.transAxes)

#plt.xlim(reversed(plt.xlim()))


for line in range(0,others.shape[0]):
     ax.text(others['kick_distance'][line]+0.015, others['epa'][line], others['posteam'][line], horizontalalignment='left', size='small', color='darkgray', weight='semibold')
        
# Plotting and labeling SF
        
ax = sns.scatterplot(x="kick_distance", 
                     y="epa",
                     hue="posteam", 
                     palette=team_colors_gray,
                     data=data[data['posteam'] == 'SF'],
                     legend=False,
                     alpha=0.8,
                     s=600
                    )

ax.set_ylabel('EPA per punt\n')
ax.set_xlabel('\nKick distance per punt')

ax.text(data[data['posteam'] == 'SF']['kick_distance']+0.015, data[data['posteam'] == 'SF']['epa'], data[data['posteam'] == 'SF']['posteam'].values[0], horizontalalignment='left', size=20, color='black', weight='semibold')
sns.despine(left=True, right=True, top=True, bottom=True)
